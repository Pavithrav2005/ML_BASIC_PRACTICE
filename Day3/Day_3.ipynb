# %% [markdown]
# # **Import Necessary libraries**(Pandas)

# %%
import pandas as pd

# %% [markdown]
# ## **PANDAS contains two structures:**
#
#
# 1.  **Series** -   1D array stores integer,float,string,etc..
# 2.   **DataFrame** - 2D array

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### **Index refers to rows and renamed as r1,r2,r3**

# %%
lst=['ab','cd','ef']
df=pd.DataFrame(lst,columns=['col1'],index=['r1','r2','r3'])
df
# Out:
#    col1
# r1   ab
# r2   cd
# r3   ef

# %% [markdown]
# ### **Numeric Operations in pandas**

# %%
a=pd.Series([1,2,3,4])
b=pd.Series([2,3,4])
a+b
# Out:
# 0    3.0
# 1    5.0
# 2    7.0
# 3    NaN
# dtype: float64
